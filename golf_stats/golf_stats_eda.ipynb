# %%
# Number of Rounds
# Fairway Percentage
# year
# avg distance from tee
# greens in regulation
# average putts
# average scrambling
# average score
# average strokes gained putting
# average strokes gained total
# strokes gained off the tee
# strokes gained approach the green
# strokes gained around teh green
